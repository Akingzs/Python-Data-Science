# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
#     Reading external data

# %%
df = pd.read_csv(r'C:\Users\arthur.oliveira\OneDrive\Study\Python-Data-Science\Pandas\database\btc-market-price.csv', header=None)

# %%
df
# Out:
#                        0            1
# 0    2017-04-02 00:00:00  1099.169125
# 1    2017-04-03 00:00:00  1141.813000
# 2    2017-04-04 00:00:00  1141.600363
# 3    2017-04-05 00:00:00  1133.079314
# 4    2017-04-06 00:00:00  1196.307937
# ..                   ...          ...
# 360  2018-03-28 00:00:00  7960.380000
# 361  2018-03-29 00:00:00  7172.280000
# 362  2018-03-30 00:00:00  6882.531667
# 363  2018-03-31 00:00:00  6935.480000
# 364  2018-04-01 00:00:00  6794.105000
#
# [365 rows x 2 columns]

# %%
df.columns = ['Timestamps','Price']

# %%
df
# Out:
#               Timestamps        Price
# 0    2017-04-02 00:00:00  1099.169125
# 1    2017-04-03 00:00:00  1141.813000
# 2    2017-04-04 00:00:00  1141.600363
# 3    2017-04-05 00:00:00  1133.079314
# 4    2017-04-06 00:00:00  1196.307937
# ..                   ...          ...
# 360  2018-03-28 00:00:00  7960.380000
# 361  2018-03-29 00:00:00  7172.280000
# 362  2018-03-30 00:00:00  6882.531667
# 363  2018-03-31 00:00:00  6935.480000
# 364  2018-04-01 00:00:00  6794.105000
#
# [365 rows x 2 columns]

# %%
df.shape
# Out:
# (365, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Timestamps  365 non-null    object
#  1   Price       365 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 5.8+ KB

# %%
df['Timestamps'] = pd.to_datetime(df['Timestamps'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Timestamps  365 non-null    datetime64[ns]
#  1   Price       365 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 5.8 KB

# %%
df.head(10)
# Out:
#   Timestamps        Price
# 0 2017-04-02  1099.169125
# 1 2017-04-03  1141.813000
# 2 2017-04-04  1141.600363
# 3 2017-04-05  1133.079314
# 4 2017-04-06  1196.307937
# 5 2017-04-07  1190.454250
# 6 2017-04-08  1181.149838
# 7 2017-04-09  1208.800500
# 8 2017-04-10  1207.744875
# 9 2017-04-11  1226.617037

# %%
df.set_index('Timestamps',inplace=True)

# %%
df
# Out:
#                   Price
# Timestamps
# 2017-04-02  1099.169125
# 2017-04-03  1141.813000
# 2017-04-04  1141.600363
# 2017-04-05  1133.079314
# 2017-04-06  1196.307937
# ...                 ...
# 2018-03-28  7960.380000
# 2018-03-29  7172.280000
# 2018-03-30  6882.531667
# 2018-03-31  6935.480000
# 2018-04-01  6794.105000
#
# [365 rows x 1 columns]

# %%
# Doing all steps only in read_csv
df = pd.read_csv(
    r'C:\Users\arthur.oliveira\OneDrive\Study\Python-Data-Science\Pandas\database\btc-market-price.csv',
    header=None,
    names=['Timestamp', 'Price'],
    index_col=0,
    parse_dates=True
)

# %%
df
# Out:
#                   Price
# Timestamp
# 2017-04-02  1099.169125
# 2017-04-03  1141.813000
# 2017-04-04  1141.600363
# 2017-04-05  1133.079314
# 2017-04-06  1196.307937
# ...                 ...
# 2018-03-28  7960.380000
# 2018-03-29  7172.280000
# 2018-03-30  6882.531667
# 2018-03-31  6935.480000
# 2018-04-01  6794.105000
#
# [365 rows x 1 columns]

# %% [markdown]
#     Plotting basics

# %%
df.plot()
# Out:
# <Axes: xlabel='Timestamp'>

# %%
plt.plot(df.index, df['Price'])

# %%
x = np.arange(-10,11)

# %%
plt.plot(x,x**2)

# %%
plt.figure(figsize=(12, 6))
plt.plot(x, x ** 2)
plt.plot(x, -1 * (x ** 2))

plt.title('My Nice Plot')
# Out:
# Text(0.5, 1.0, 'My Nice Plot')
