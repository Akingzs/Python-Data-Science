# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
path_por = r"C:\Users\arthur.oliveira\OneDrive\Study\alcohol\student-por.csv"
path_mat = r"C:\Users\arthur.oliveira\OneDrive\Study\alcohol\student-mat.csv"
df_mat = pd.read_csv(path_mat)
df_por = pd.read_csv(path_por)

# %%
df = pd.concat([df_mat, df_por])

# %%
df.count()
# Out:
# school        1044
# sex           1044
# age           1044
# address       1044
# famsize       1044
# Pstatus       1044
# Medu          1044
# Fedu          1044
# Mjob          1044
# Fjob          1044
# reason        1044
# guardian      1044
# traveltime    1044
# studytime     1044
# failures      1044
# schoolsup     1044
# famsup        1044
# paid          1044
# activities    1044
# nursery       1044
# higher        1044
# internet      1044
# romantic      1044
# famrel        1044
# freetime      1044
# goout         1044
# Dalc          1044
# Walc          1044
# health        1044
# absences      1044
# G1            1044
# G2            1044
# G3            1044
# dtype: int64

# %%
df.corr(method='pearson', min_periods=1, numeric_only=True)
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.130196 -0.138521    0.049216  -0.007870  0.282364
# Medu       -0.130196  1.000000  0.642063   -0.238181   0.090616 -0.187769
# Fedu       -0.138521  0.642063  1.000000   -0.196328   0.033458 -0.191390
# traveltime  0.049216 -0.238181 -0.196328    1.000000  -0.081328  0.087177
# studytime  -0.007870  0.090616  0.033458   -0.081328   1.000000 -0.152024
# failures    0.282364 -0.187769 -0.191390    0.087177  -0.152024  1.000000
# famrel      0.007162  0.015004  0.013066   -0.012578   0.012324 -0.053676
# freetime    0.002645  0.001054  0.002142   -0.007403  -0.094429  0.102679
# goout       0.118510  0.025614  0.030075    0.049740  -0.072941  0.074683
# Dalc        0.133453  0.001515 -0.000165    0.109423  -0.159665  0.116336
# Walc        0.098291 -0.029331  0.019524    0.084292  -0.229073  0.107432
# health     -0.029129 -0.013254  0.034288   -0.029002  -0.063044  0.048311
# ...

# %%
sns.heatmap(df.corr(method='pearson', min_periods=1, numeric_only=True),annot = True,fmt = ".1f",cbar = True)
# Out:
# <Axes: >
