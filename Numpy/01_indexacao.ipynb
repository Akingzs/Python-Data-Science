# %%
import numpy as np
from PIL import Image
from IPython.display import display

# %%
arr1 = np.array([1,2,3,4,5,6,7,8])

# %%
print(arr1)
# Out:
# [1 2 3 4 5 6 7 8]

# %%
np.shape(arr1)
# Out:
# (8,)

# %%
img = Image.open('array_shapes.png')

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1024x572>

# %%
np.linspace(0,10,3)
# Out:
# array([ 0.,  5., 10.])

# %%
arr1[0:4]
# Out:
# array([1, 2, 3, 4])

# %%
indices = [0,2,4]
arr1[indices]
# Out:
# array([1, 3, 5])

# %%
mask  = (arr1 % 2 == 0)

# %%
mask
# Out:
# array([False,  True, False,  True, False,  True, False,  True])

# %%
arr1[mask]
# Out:
# array([2, 4, 6, 8])

# %%
# Arrays do not accept different type of values in the same array
arr1[0] = 100
arr1
# Out:
# array([100,   2,   3,   4,   5,   6,   7,   8])
