# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Importanto bases
pref_consumidor = r'c:\Users\arthur.oliveira\OneDrive\Codes\Database\Restaurant_Ratings\consumer_preferences.csv'
consumidor = r'c:\Users\arthur.oliveira\OneDrive\Codes\Database\Restaurant_Ratings\consumers.csv'
rating = r'c:\Users\arthur.oliveira\OneDrive\Codes\Database\Restaurant_Ratings\ratings.csv'
restaurantes = r'c:\Users\arthur.oliveira\OneDrive\Codes\Database\Restaurant_Ratings\restaurants.csv'
cozinhas = r'c:\Users\arthur.oliveira\OneDrive\Codes\Database\Restaurant_Ratings\restaurant_cuisines.csv'

# %%
# Atribuindo caminho a um df
df_pref = pd.read_csv(pref_consumidor)
df_consumidor = pd.read_csv(consumidor)
df_rating = pd.read_csv(rating)
df_rest = pd.read_csv(restaurantes)
df_cozinhas = pd.read_csv(cozinhas)

# %%
df_cozinhas.info()

# %%
df_rating.head()

# %%
df_rating.info()

# %%
# Realizo a media geral por ID 
rating_geral = df_rating.groupby('Restaurant_ID')['Overall_Rating'].mean()

# %%
rating_geral

# %%
df_rest.describe()

# %%
# Transformo a media geral em um df para depois unir com outra tabela
rating_geral.to_frame()

# %%
# Reseto o index para que a cooluna do ID vire uma coluna ao inves de ser meu indice
rating_geral.reset_index()

# %%
# Merge na tabela de restaurante com a media geral
merged_df = pd.merge(df_rest, rating_geral, on='Restaurant_ID')

# %%
merged_df
# Out:
#      Restaurant_ID                        Name             City  \
# 0           132560          Puesto de Gorditas  Ciudad Victoria
# 1           132561                  Cafe Ambar  Ciudad Victoria
# 2           132564                    Church's  Ciudad Victoria
# 3           132572                Cafe Chaires  San Luis Potosi
# 4           132583            McDonalds Centro       Cuernavaca
# ..             ...                         ...              ...
# 125         135088           Cafeteria Cenidet       Cuernavaca
# 126         135104                        Vips  Ciudad Victoria
# 127         135106  El Rincón De San Francisco  San Luis Potosi
# 128         135108                  Potzocalli  San Luis Potosi
# 129         135109                   Paniroles       Cuernavaca
#
#                State Country  Zip_Code   Latitude   Longitude Alcohol_Service  \
# 0         Tamaulipas  Mexico       NaN  23.752304  -99.166913            None
# ...

# %%
cozinha_grupo = df_cozinhas.groupby('Restaurant_ID')['Cuisine'].apply(','.join).reset_index()

# %%
df_cozinhas['Restaurant_ID'].value_counts()
# Out:
# 134976    3
# 135053    3
# 135043    2
# 135032    2
# 132866    2
#          ..
# 132845    1
# 132834    1
# 132825    1
# 132768    1
# 135109    1
# Name: Restaurant_ID, Length: 95, dtype: int64

# %%
cozinha_grupo_filtrado = cozinha_grupo.loc[cozinha_grupo['Restaurant_ID'] == 134976]

# %%
cozinha_grupo_filtrado
# Out:
#     Restaurant_ID                        Cuisine
# 51         134976  Mexican,Mediterranean,Burgers

# %%
# Merge na tabela de restaurante com a media geral
merged_df = pd.merge(merged_df, cozinha_grupo, on='Restaurant_ID')

# %%
merged_df
# Out:
#     Restaurant_ID                                Name             City  \
# 0          132560                  Puesto de Gorditas  Ciudad Victoria
# 1          132572                        Cafe Chaires  San Luis Potosi
# 2          132583                    McDonalds Centro       Cuernavaca
# 3          132584                  Gorditas Doña Tota  Ciudad Victoria
# 4          132594  Tacos De Barbacoa Enfrente Del Tec  Ciudad Victoria
# ..            ...                                 ...              ...
# 90         135086         McDonalds Parque Tangamanga  San Luis Potosi
# 91         135088                   Cafeteria Cenidet       Cuernavaca
# 92         135104                                Vips  Ciudad Victoria
# 93         135106          El Rincón De San Francisco  San Luis Potosi
# 94         135109                           Paniroles       Cuernavaca
#
#               State Country  Zip_Code   Latitude   Longitude Alcohol_Service  \
# ...
