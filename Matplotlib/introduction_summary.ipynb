# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Global API

# %%
x = np.arange(-10,11)

# %%
plt.figure(figsize=(12,6))
plt.title('My Plot')
plt.plot(x, x ** 2)
plt.plot(x, -1 * (x ** 2))

# %%
plt.figure(figsize=(15,6))
plt.title('My second plot')

plt.subplot(1, 2, 1)
plt.plot(x, x ** 2)
plt.plot([0,0,0],[-10,0,100])
plt.legend(['X^2', 'Vertical Line'])


plt.subplot(1, 2, 2)
plt.plot(x, -1 * (x ** 2))
plt.plot([-10, 0, 10], [-50, -50, -50])
plt.legend(['-X^2', 'Horizontal Line'])

# %% [markdown]
# OOP Interface

# %%
fig, axes = plt.subplots(figsize=(12,6))

# %%
fig, axes = plt.subplots(figsize=(12,6))
axes.plot(x, x**2, color='red', linewidth=3, marker='o', label='X^2')
axes.plot(x, -1 * (x**2), 'b--')
axes.set_xlabel('X')
axes.set_ylabel('X^2')
axes.set_title('My plot')
# fig
# Out:
# Text(0.5, 1.0, 'My plot')

# %%
fig, axes = plt.subplots(figsize=(12, 6))

axes.plot(x, x + 0, linestyle='solid')
axes.plot(x, x + 1, linestyle='dashed')
axes.plot(x, x + 2, linestyle='dashdot')
axes.plot(x, x + 3, linestyle='dotted');

axes.set_title("My Nice Plot")
# Out:
# Text(0.5, 1.0, 'My Nice Plot')

# %%
fig, axes = plt.subplots(figsize=(12, 6))

axes.plot(x, x + 0, '-og', label="solid green")
axes.plot(x, x + 1, '--c', label="dashed cyan")
axes.plot(x, x + 2, '-.b', label="dashdot blue")
axes.plot(x, x + 3, ':r', label="dotted red")

axes.set_title("My Nice Plot")

axes.legend()

# %% [markdown]
# Other types of plots

# %%
plot_obj = plt.subplots()
fig, ax = plot_obj

ax.plot([1,2,4],[1,2,4])

# %%
plot_objects = plt.subplots(nrows=2, ncols=2, figsize=(14, 6))

fig, ((ax1, ax2), (ax3, ax4)) = plot_objects

plot_objects
# Out:
# (<Figure size 1400x600 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))

# %%
ax3.plot(np.random.randn(10), c='blue')
ax2.plot(np.random.randn(10), c='red', linestyle='--')
ax1.plot(np.random.randn(10), c='yellow', linestyle='--')
ax4.plot(np.random.randn(10), c='green', linestyle=':', linewidth=2)
fig

# %%
np.random.randn(5)
# Out:
# array([-0.19135009,  0.85758081,  1.43328897,  2.31497804,  0.66536124])

# %% [markdown]
# Scatter Plot

# %%
N = 50 
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (20 * np.random.rand(N))**2  # 0 to 15 point radii

# %%
fig, ax = plt.subplots(figsize=(12,6))
scatter = ax.scatter(x,y, s=area, c=colors, cmap='Spectral')
fig.colorbar(scatter)

# %%
fig = plt.figure(figsize=(14, 6))

ax1 = fig.add_subplot(1,2,1)
plt.scatter(x, y, s=area, c=colors, alpha=0.5, cmap='Pastel1')
plt.colorbar()

ax2 = fig.add_subplot(1,2,2)
plt.scatter(x, y, s=area, c=colors, alpha=0.5, cmap='Pastel2')
plt.colorbar()

plt.show()

# %% [markdown]
# Histograms

# %%
values = np.random.randn(1000)

# %%
plt.subplots(figsize=(12, 6))

plt.hist(values, bins=100, alpha=0.8,
          histtype='bar', color='steelblue',
          edgecolor='green')
plt.xlim(xmin=-5, xmax=5)

plt.show()

# %% [markdown]
# Combine plots

# %%
values2 = np.linspace(min(values)-10, max(values)+10, 100)

# %%
plt.subplots(figsize=(12, 6))

plt.hist(values, bins=100, alpha=0.8, density=1,
          histtype='bar', color='steelblue',
          edgecolor='green')

plt.plot(values2, density(values2), color='#FF7F00', linewidth=3.0)
plt.xlim(xmin=-5, xmax=5)

plt.show()

# %% [markdown]
# Bar plots

# %%
Y = np.random.rand(1, 5)[0]
Y2 = np.random.rand(1, 5)[0]

# %%
Y
# Out:
# array([0.90875441, 0.67665941, 0.60477363, 0.58801359, 0.10103564])

# %%
plt.figure(figsize=(12, 4))

barWidth = 0.5
plt.bar(np.arange(len(Y)), Y, width=barWidth, color='#00b894')

plt.show()

# %%
plt.figure(figsize=(12, 4))

barWidth = 0.5
plt.bar(np.arange(len(Y)), Y, width=barWidth, color='#00b894', label='Label Y')
plt.bar(np.arange(len(Y2)), Y2, width=barWidth, color='#e17055', bottom=Y, label='Label Y2')

plt.legend()
plt.show()
