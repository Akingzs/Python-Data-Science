# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
path21= r"C:\Users\mrthu\OneDrive\Study\A3 - 2023\world-happiness-report-2021\world-happiness-report-2021.csv"
path = r"C:\Users\mrthu\OneDrive\Study\A3 - 2023\world-happiness-report-2021\world-happiness-report.csv"
df21 = pd.read_csv(path21)
dfall = pd.read_csv(path)

# %%
df21.info()

# %%
dfall.info()

# %%
a = dfall['year'].unique()
a.sort()
print(a)
# Out:
# [2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018
#  2019 2020]

# %%
dfall.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  1949.000000  1949.000000         1913.000000     1936.000000
# mean   2013.216008     5.466705            9.368453        0.812552
# std       4.166828     1.115711            1.154084        0.118482
# min    2005.000000     2.375000            6.635000        0.290000
# 25%    2010.000000     4.640000            8.464000        0.749750
# 50%    2013.000000     5.386000            9.460000        0.835500
# 75%    2017.000000     6.283000           10.353000        0.905000
# max    2020.000000     8.019000           11.648000        0.987000
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       1894.000000                   1917.000000
# mean                          63.359374                      0.742558
# std                            7.510245                      0.142093
# min                           32.300000                      0.258000
# ...

# %%
# Obtenha as colunas de cada DataFrame
colunas_df1 = set(df21.columns)
colunas_df2 = set(dfall.columns)

# Encontre as colunas em comum
colunas_comuns = colunas_df1.intersection(colunas_df2)

print('Colunas em comum:', colunas_comuns)
# Out:
# Colunas em comum: {'Freedom to make life choices', 'Social support', 'Country name', 'Generosity', 'Perceptions of corruption'}

# %%
# Acho a correlacao entre os campos, usando pearson
dfall.corr(method='pearson', min_periods=1, numeric_only=True)
# Out:
#                                       year  Life Ladder  Log GDP per capita  \
# year                              1.000000     0.035515            0.078246
# Life Ladder                       0.035515     1.000000            0.790166
# Log GDP per capita                0.078246     0.790166            1.000000
# Social support                   -0.010093     0.707806            0.692602
# Healthy life expectancy at birth  0.164059     0.744506            0.848049
# Freedom to make life choices      0.222151     0.528063            0.367932
# Generosity                       -0.043422     0.190632           -0.000915
# Perceptions of corruption        -0.081478    -0.427245           -0.345511
# Positive affect                  -0.003245     0.532273            0.302282
# Negative affect                   0.196869    -0.297488           -0.210781
#
#                                   Social support  \
# year                                   -0.010093
# ...

# %%
sns.heatmap(dfall.corr(method='pearson', min_periods=1, numeric_only=True),annot = True,fmt = ".1f",cbar = True)
# Out:
# <Axes: >
